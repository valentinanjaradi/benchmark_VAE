# %%
import torchvision 
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
if 'results/mnist_ae_grid' and 'local' in 'results/mnist_ae_grid':
    print('yes')
else:    print('no')
# Out:
# no

# %%
n_b = 50
n_d = 50

# %%
train_ds = datasets.MNIST("examples/scripts/data/mnist", train=True,  download=True, transform=None)
test_ds  = datasets.MNIST("examples/scripts/data/mnist", train=False, download=True, transform=None)

X_base = train_ds.data[:n_b,:] / 255
X_downstream = train_ds.data[n_b:n_b+n_d, :] / 255
y_downstream = train_ds.targets[n_b:n_b+n_d]
X_test = test_ds.data / 255
y_test = test_ds.targets

# %%
plt.hist(X_base.numpy().flatten(), bins=50)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
X = train_dataset.reshape(-1, 32*32*3) / 255.0

# %%
X.shape
# Out:
# (50000, 3072)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
eigvals, eigvecs = np.linalg.eig(X.T @ X / X.shape[0])

# %%
plt.hist(eigvals, bins=200)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %%
import numpy as np

# %%
m_values = np.linspace(14, 28*28, num=10).astype(int)  # from very small to full dimension

# %%
np.logspace(1, 12, base=2, num=10).astype(int)
# Out:
# array([   2,    4,   10,   25,   59,  138,  322,  752, 1755, 4096])

# %%
np.linspace(1,1000,6).astype(int)
# Out:
# array([   1,  200,  400,  600,  800, 1000])

# %%
np.append(np.logspace(1, 9, num=14, base=2).astype(int), 28*28)
# Out:
# array([  2,   3,   4,   7,  11,  16,  25,  39,  60,  92, 142, 218, 334,
#        512, 784])

# %%
2**9
# Out:
# 512
